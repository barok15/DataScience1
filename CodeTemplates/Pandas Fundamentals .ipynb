# %%
import pandas as pd
import random

# %%
# Challenge 1
df = pd.read_csv("C:/Users/btsegaye/Downloads/pirates.csv") # This requires the csv file to be in the same folder as this Jupyter notebook.

# %%
# Challlenge 2 - Part 1 & 2
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1000 non-null   int64
#  1   sex              1000 non-null   object
#  2   age              999 non-null    float64
#  3   height           1000 non-null   float64
#  4   weight           1000 non-null   float64
#  5   headband         999 non-null    object
#  6   college          1000 non-null   object
#  7   tattoos          1000 non-null   int64
#  8   tchests          1000 non-null   int64
#  9   parrots          1000 non-null   object
#  10  favorite.pirate  999 non-null    object
#  11  sword.type       1000 non-null   object
#  12  eyepatch         1000 non-null   int64
#  13  sword.time       999 non-null    float64
#  14  beard.length     1000 non-null   int64
#  15  fav.pixar        1000 non-null   object
# ...

# %%
# Challenge 2 - Part 3
for column in df.columns:
    for row in range(len(df["id"])):
        if pd.isna(df.loc[row, column]):
            print(row + 1)
            print(column)
# Out:
# 34
# age
# 1000
# headband
# 635
# favorite.pirate
# 137
# sword.time

# %%
# Challenge 3
# Technique 1
# This drops all rows that contain a null value

df.dropna()
# Out:
#       id     sex   age  height  weight headband college  tattoos  tchests  \
# 0      1    male  28.0  173.11    70.5      yes   JSSFP        9        0
# 1      2    male  31.0  209.25   105.6      yes   JSSFP        9       11
# 2      3    male  26.0  169.95    77.1      yes    CCCC       10       10
# 3      4  female  31.0  144.29    58.5       no   JSSFP        2        0
# 4      5  female  41.0  157.85    58.4      yes   JSSFP        9        6
# ..   ...     ...   ...     ...     ...      ...     ...      ...      ...
# 994  995    male  34.0  172.45    75.0      yes   JSSFP        9       18
# 995  996    male  26.0  178.83    70.8      yes    CCCC       14       11
# 996  997  female  34.0  157.20    53.6      yes   JSSFP       13       48
# 997  998    male  36.0  175.74    72.4      yes   JSSFP        9       95
# 998  999    male  30.0  175.24    70.2      yes   JSSFP        9        6
#
#     parrots favorite.pirate sword.type  eyepatch  sword.time  beard.length  \
# ...

# %%
# Challenge 3
# Technique 2
# Drops just the age row that features a null

df.drop(33, inplace=True)

# %%
# Challenge 3
# Technique 3
# Reassigns the missing value in age to the mean of ages

df.loc[33, "age"] = df["age"].mean()

# %%
# Challenge 3
# Technique 4
# Reassigns the missing value in favorite.pirate to the mode

df.loc[634, "favorite.pirate"] = df["favorite.pirate"].mode()[0]

# %%
# Challenge 3
# Technique 5
# Assigns the missing age value to a random integer in the range of the smallest age in the dataset and the largest age in dataset
df.loc[33, "age"] = random.randint(df["age"].min(), df["age"].max())

# %%
#Challange 4 | 1 
unique_genders = df['sex'].unique()
print(unique_genders)
print(len(unique_genders))
# Out:
# ['male' 'female' 'other' nan]
# 4

# %%
#Challange 4 | 2
avg = df['age'].mean()
print(avg)

female_pirates = df[df['sex'] == 'female']
avg_age_female = female_pirates['age'].mean()
print(avg_age_female)
# Out:
# 27.347
# 29.922246220302377

# %%
df.dropna(inplace=True)
df
# Out:
#         id     sex   age  height  weight headband college  tattoos  tchests  \
# 0      1.0    male  28.0  173.11    70.5      yes   JSSFP      9.0      0.0
# 1      2.0    male  31.0  209.25   105.6      yes   JSSFP      9.0     11.0
# 2      3.0    male  26.0  169.95    77.1      yes    CCCC     10.0     10.0
# 3      4.0  female  31.0  144.29    58.5       no   JSSFP      2.0      0.0
# 4      5.0  female  41.0  157.85    58.4      yes   JSSFP      9.0      6.0
# ..     ...     ...   ...     ...     ...      ...     ...      ...      ...
# 994  995.0    male  34.0  172.45    75.0      yes   JSSFP      9.0     18.0
# 995  996.0    male  26.0  178.83    70.8      yes    CCCC     14.0     11.0
# 996  997.0  female  34.0  157.20    53.6      yes   JSSFP     13.0     48.0
# 997  998.0    male  36.0  175.74    72.4      yes   JSSFP      9.0     95.0
# 998  999.0    male  30.0  175.24    70.2      yes   JSSFP      9.0      6.0
#
# ...

# %%
#Challange 4 | 3
count = 0 
for x in df['weight']: 
    if x < 100: 
        count += x
        
percent_weight =  ( x / len(df['weight']) ) * 100
print(percent_weight, '%')
# Out:
# 7.0411233701103315 %

# %%
#Challange 5 | 1 
shortest_pirate == df['height'].min()
shortest_pirate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14508\3280148881.py in <module>
#       1 #Challange 5 | 1
# ----> 2 shortest_pirate == df['height'].min()
#       3 shortest_pirate
#
# NameError: name 'shortest_pirate' is not defined

# %%
heaviest_pirate == df['weight'].max()
print(heaviest_pirate)

# %%
fav_movie = df['fav.pixar'].mode()
print(fav_movie)

# %%
#Challange 6 
avg_eyepatches = df['eyepatch'].mean()
median_eyepatches = df['eyepatch'].median()
difference = abs(avg_eyepatches - median_eyepatches)
print(avg_eyepatches)
print(median_eyepatches)
print(difference)
# Out:
# 0.6579739217652959
# 1.0
# 0.3420260782347041

# %%
new_data = pd.read_csv('C:/Users/btsegaye/Downloads/PirateNewRow.csv')
df = df.append(new_data, ignore_index=True)
# Out:
# C:\Users\btsegaye\AppData\Local\Temp\ipykernel_14508\2409692439.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_data, ignore_index=True)

# %%
df
# Out:
#          id     sex   age  height  weight headband college  tattoos  tchests  \
# 0       1.0    male  28.0  173.11   70.50      yes   JSSFP      9.0      0.0
# 1       2.0    male  31.0  209.25  105.60      yes   JSSFP      9.0     11.0
# 2       3.0    male  26.0  169.95   77.10      yes    CCCC     10.0     10.0
# 3       4.0  female  31.0  144.29   58.50       no   JSSFP      2.0      0.0
# 4       5.0  female  41.0  157.85   58.40      yes   JSSFP      9.0      6.0
# ..      ...     ...   ...     ...     ...      ...     ...      ...      ...
# 993   996.0    male  26.0  178.83   70.80      yes    CCCC     14.0     11.0
# 994   997.0  female  34.0  157.20   53.60      yes   JSSFP     13.0     48.0
# 995   998.0    male  36.0  175.74   72.40      yes   JSSFP      9.0     95.0
# 996   999.0    male  30.0  175.24   70.20      yes   JSSFP      9.0      6.0
# 997  1001.0  female  43.0  187.30   97.12       no    CCCC     17.0      3.0
#
# ...

# %%
new_column = pd.read_csv('C:/Users/btsegaye/Downloads/PirateNewColumn.csv')
new_column
# Out:
#       id       favorite.sea
# 0    178         Bering Sea
# 1     92     Gulf of Alaska
# 2     25       Ligurian Sea
# 3    719        Chilean Sea
# 4     16      Norwegian Sea
# ..   ...                ...
# 995  423  Mediterranean Sea
# 996  727        Barents Sea
# 997  727         Bering Sea
# 998  986          Banda Sea
# 999  456       Adriatic Sea
#
# [1000 rows x 2 columns]

# %%
df = df.append(new_column, ignore_index=True)
df
# Out:
# C:\Users\btsegaye\AppData\Local\Temp\ipykernel_14508\1822344847.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(new_column, ignore_index=True)
#          id     sex   age  height  weight headband college  tattoos  tchests  \
# 0       1.0    male  28.0  173.11    70.5      yes   JSSFP      9.0      0.0
# 1       2.0    male  31.0  209.25   105.6      yes   JSSFP      9.0     11.0
# 2       3.0    male  26.0  169.95    77.1      yes    CCCC     10.0     10.0
# 3       4.0  female  31.0  144.29    58.5       no   JSSFP      2.0      0.0
# 4       5.0  female  41.0  157.85    58.4      yes   JSSFP      9.0      6.0
# ...     ...     ...   ...     ...     ...      ...     ...      ...      ...
# 1993  423.0     NaN   NaN     NaN     NaN      NaN     NaN      NaN      NaN
# 1994  727.0     NaN   NaN     NaN     NaN      NaN     NaN      NaN      NaN
# ...
